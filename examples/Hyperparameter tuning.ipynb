# %% [markdown]
# # Imports + Path Specification

# %%
import sys
import os
import torch
from torch import optim
from time import time

# %%
# tile2vec_dir = '/home/agupta21/gcloud/231n_gitproject'
tile2vec_dir = '/home/shailimonchik/project'
sys.path.append('../')
sys.path.append(tile2vec_dir)

# %%
from src.datasets import TileTripletsDataset, GetBands, RandomFlipAndRotate, ClipAndScale, ToFloatTensor, triplet_dataloader
from src.tilenet import make_tilenet

# %%
from src.training import prep_triplets, train_triplet_epoch

# %%
import numpy as np
from torch.autograd import Variable
import sys
from src.resnet import ResNet18

# %%
#Random Forest Classification

from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Dataloader + TileNet Setup

# %%
# Environment stuff
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
cuda = torch.cuda.is_available()
print(cuda)
# Out:
# True

# %%
# Defining Parameters
img_type = 'naip'
tile_dir = '/home/shailimonchik/project/data_temp/data/triplets/'
bands = 4
augment = False
batch_size = 50
shuffle = True
num_workers = 4
n_triplets = 108700 #modification: adding 8700 more for semi-supervised learning purposes

# %%
dataloader = triplet_dataloader(img_type, tile_dir, bands=bands, augment=augment,
                                batch_size=batch_size, shuffle=shuffle, num_workers=num_workers, 
                                n_triplets=n_triplets, pairs_only=False)
print('Dataloader set up complete.')
# Out:
# Dataloader set up complete.

# %%
in_channels = bands
z_dim = 512

# %%
TileNet = make_tilenet(in_channels=in_channels, z_dim=z_dim)
TileNet.train()
if cuda: TileNet.cuda()
print('TileNet set up complete.')
# Out:
# TileNet set up complete.

# %%
#Hyperparameters to tune 
learning_rates = [1e-2, 3e-2, 1e-3, 3e-3, 1e-4, 3e-4]
betas = [0.5, 0.6, 0.7, 0.8, 0.9]
margins = [10, 15, 20, 25, 30]

# %% [markdown]
# # Training Model + Writing Each Epoch to File

# %%
epochs = 5
# margin = 10
l2 = 0.01
print_every = 10000
save_models = True

# %%
model_dir = '/home/shailimonchik/project/models/'
if not os.path.exists(model_dir): os.makedirs(model_dir)

# %%
#### best_params = None
all_plots = []
best_avg_loss = None
best_params = None
print('Begin learning.................')
for margin in margins:
    for lr in learning_rates:
        for beta1 in betas:
            print('lr: {}, beta1: {}, margin: {}'.format(lr, beta1, margin))
            params = (lr, beta1, margin)
            optimizer = optim.Adam(TileNet.parameters(), lr=lr, betas=(beta1, 0.999))
            t0 = time()
            #with open(results_fn, 'w') as file:
            plot_list = []
            for epoch in range(0, epochs):
                (avg_loss, avg_l_n, avg_l_d, avg_l_nd) = train_triplet_epoch(
                    TileNet, cuda, dataloader, optimizer, epoch+1, margin=margin, l2=l2,
                    print_every=print_every, t0=t0, hyper_tuning=True)
                plot_list.append((epoch+1,avg_loss))
                append_name = "hyper_tuning_ep" + str(epoch+1) + "lr_" + str(lr) + "beta1_" + str(beta1) + "margin_"+ str(margin) + ".ckpt" # change test1_ep
                if save_models:
                    model_fn = os.path.join(model_dir,append_name)
                    torch.save(TileNet.state_dict(),model_fn)
            if best_params == None or plot_list[len(plot_list) - 1][1] < best_avg_loss:
                best_params = params
                best_avg_loss = plot_list[len(plot_list) - 1][1]
            all_plots.append((params, plot_list))
# Out:
# Begin learning.................
# lr: 0.01, beta1: 0.5, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 106.269s
#   Average loss: 0.2382
#   Average l_n: 0.2218
#   Average l_d: -0.6929
#   Average l_nd: -0.4712
#
# yy
# breaking
# 100
# Finished epoch 2: 213.969s
#   Average loss: 0.2420
#   Average l_n: 0.2256
#   Average l_d: -0.6923
#   Average l_nd: -0.4667
#
# yy
# breaking
# 100
# Finished epoch 3: 321.713s
#   Average loss: 0.2361
#   Average l_n: 0.2229
#   Average l_d: -0.6962
#   Average l_nd: -0.4733
#
# yy
# breaking
# 100
# Finished epoch 4: 429.127s
#   Average loss: 0.2364
#   Average l_n: 0.2203
#   Average l_d: -0.6876
#   Average l_nd: -0.4673
#
# yy
# breaking
# 100
# Finished epoch 1: 106.542s
#   Average loss: 0.2345
#   Average l_n: 0.2168
#   Average l_d: -0.6897
#   Average l_nd: -0.4729
#
# yy
# breaking
# 100
# Finished epoch 2: 213.256s
#   Average loss: 0.2304
#   Average l_n: 0.2157
#   Average l_d: -0.6938
#   Average l_nd: -0.4781
#
# yy
# breaking
# 100
# Finished epoch 3: 319.591s
#   Average loss: 0.2340
#   Average l_n: 0.2187
#   Average l_d: -0.6916
#   Average l_nd: -0.4729
#
# yy
# breaking
# 100
# Finished epoch 4: 425.462s
#   Average loss: 0.2321
#   Average l_n: 0.2176
#   Average l_d: -0.6938
#   Average l_nd: -0.4762
#
# yy
# breaking
# 100
# Finished epoch 5: 530.894s
#   Average loss: 0.2332
#   Average l_n: 0.2225
#   Average l_d: -0.6949
#   Average l_nd: -0.4725
#
# lr: 0.01, beta1: 0.7, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 105.676s
#   Average loss: 0.2313
#   Average l_n: 0.2144
#   Average l_d: -0.6886
#   Average l_nd: -0.4742
#
# yy
# breaking
# 100
# Finished epoch 2: 211.460s
#   Average loss: 0.2303
#   Average l_n: 0.2197
#   Average l_d: -0.6955
#   Average l_nd: -0.4759
#
# yy
# breaking
# 100
# Finished epoch 3: 317.273s
#   Average loss: 0.2301
#   Average l_n: 0.2165
#   Average l_d: -0.6889
#   Average l_nd: -0.4723
#
# yy
# breaking
# 100
# Finished epoch 4: 423.120s
#   Average loss: 0.2260
#   Average l_n: 0.2121
#   Average l_d: -0.6909
#   Average l_nd: -0.4788
#
# yy
# breaking
# 100
# Finished epoch 5: 528.886s
#   Average loss: 0.2276
#   Average l_n: 0.2134
#   Average l_d: -0.6932
#   Average l_nd: -0.4798
#
# lr: 0.01, beta1: 0.8, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 105.483s
#   Average loss: 0.2305
#   Average l_n: 0.2210
#   Average l_d: -0.6949
#   Average l_nd: -0.4739
#
# yy
# breaking
# 100
# Finished epoch 2: 211.025s
#   Average loss: 0.2279
#   Average l_n: 0.2108
#   Average l_d: -0.6827
#   Average l_nd: -0.4719
#
# yy
# breaking
# 100
# Finished epoch 3: 317.220s
#   Average loss: 0.2271
#   Average l_n: 0.2097
#   Average l_d: -0.6844
#   Average l_nd: -0.4747
#
# yy
# breaking
# 100
# Finished epoch 4: 423.763s
#   Average loss: 0.2275
#   Average l_n: 0.2155
#   Average l_d: -0.6911
#   Average l_nd: -0.4756
#
# yy
# breaking
# 100
# Finished epoch 5: 529.592s
#   Average loss: 0.2275
#   Average l_n: 0.2099
#   Average l_d: -0.6848
#   Average l_nd: -0.4749
#
# lr: 0.01, beta1: 0.9, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 106.114s
#   Average loss: 0.2286
#   Average l_n: 0.2166
#   Average l_d: -0.6973
#   Average l_nd: -0.4807
#
# yy
# breaking
# 100
# breaking
# 100
# Finished epoch 3: 317.911s
#   Average loss: 0.2235
#   Average l_n: 0.2109
#   Average l_d: -0.6900
#   Average l_nd: -0.4790
#
# yy
# breaking
# 100
# Finished epoch 4: 423.342s
#   Average loss: 0.2245
#   Average l_n: 0.2109
#   Average l_d: -0.6904
#   Average l_nd: -0.4796
#
# yy
# breaking
# 100
# Finished epoch 5: 529.271s
#   Average loss: 0.2252
#   Average l_n: 0.2098
#   Average l_d: -0.6872
#   Average l_nd: -0.4775
#
# lr: 0.03, beta1: 0.5, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 105.896s
#   Average loss: 0.2410
#   Average l_n: 0.2265
#   Average l_d: -0.7032
#   Average l_nd: -0.4767
#
# yy
# breaking
# 100
# Finished epoch 3: 317.140s
#   Average loss: 0.2367
#   Average l_n: 0.2170
#   Average l_d: -0.6959
#   Average l_nd: -0.4789
#
# yy
# breaking
# 100
# Finished epoch 4: 422.067s
#   Average loss: 0.2405
#   Average l_n: 0.2204
#   Average l_d: -0.6919
#   Average l_nd: -0.4715
#
# yy
# breaking
# 100
# Finished epoch 5: 527.715s
#   Average loss: 0.2344
#   Average l_n: 0.2125
#   Average l_d: -0.6876
#   Average l_nd: -0.4751
#
# lr: 0.03, beta1: 0.6, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 105.933s
#   Average loss: 0.2368
#   Average l_n: 0.2256
#   Average l_d: -0.7043
#   Average l_nd: -0.4788
#
# yy
# breaking
# 100
# Finished epoch 2: 211.484s
#   Average loss: 0.2335
#   Average l_n: 0.2150
#   Average l_d: -0.6926
#   Average l_nd: -0.4776
#
# yy
# breaking
# 100
# Finished epoch 3: 316.671s
#   Average loss: 0.2344
#   Average l_n: 0.2145
#   Average l_d: -0.6886
#   Average l_nd: -0.4741
#
# yy
# breaking
# 100
# Finished epoch 4: 421.929s
#   Average loss: 0.2320
#   Average l_n: 0.2153
#   Average l_d: -0.6950
#   Average l_nd: -0.4797
#
# yy
# breaking
# 100
# Finished epoch 5: 527.423s
#   Average loss: 0.2340
#   Average l_n: 0.2165
#   Average l_d: -0.6915
#   Average l_nd: -0.4751
#
# lr: 0.03, beta1: 0.7, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 105.199s
#   Average loss: 0.2314
#   Average l_n: 0.2148
#   Average l_d: -0.6966
#   Average l_nd: -0.4818
#
# yy
# breaking
# 100
# Finished epoch 2: 209.532s
#   Average loss: 0.2299
#   Average l_n: 0.2135
#   Average l_d: -0.6955
#   Average l_nd: -0.4820
#
# yy
# breaking
# 100
# Finished epoch 3: 315.204s
#   Average loss: 0.2250
#   Average l_n: 0.2119
#   Average l_d: -0.6977
#   Average l_nd: -0.4857
#
# yy
# breaking
# 100
# Finished epoch 4: 421.064s
#   Average loss: 0.2286
#   Average l_n: 0.2185
#   Average l_d: -0.7044
#   Average l_nd: -0.4858
#
# yy
# breaking
# 100
# Finished epoch 5: 526.151s
#   Average loss: 0.2263
#   Average l_n: 0.2102
#   Average l_d: -0.6922
#   Average l_nd: -0.4820
#
# lr: 0.03, beta1: 0.8, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 105.166s
#   Average loss: 0.2283
#   Average l_n: 0.2112
#   Average l_d: -0.6914
#   Average l_nd: -0.4802
#
# yy
# breaking
# 100
# breaking
# 100
# Finished epoch 3: 315.157s
#   Average loss: 0.2249
#   Average l_n: 0.2114
#   Average l_d: -0.6931
#   Average l_nd: -0.4817
#
# yy
# breaking
# 100
# Finished epoch 4: 420.401s
#   Average loss: 0.2211
#   Average l_n: 0.2094
#   Average l_d: -0.6991
#   Average l_nd: -0.4898
#
# yy
# breaking
# 100
# Finished epoch 5: 525.856s
#   Average loss: 0.2255
#   Average l_n: 0.2078
#   Average l_d: -0.6817
#   Average l_nd: -0.4739
#
# lr: 0.03, beta1: 0.9, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 105.517s
#   Average loss: 0.2247
#   Average l_n: 0.2170
#   Average l_d: -0.7016
#   Average l_nd: -0.4846
#
# yy
# breaking
# 100
# Finished epoch 2: 210.415s
#   Average loss: 0.2224
#   Average l_n: 0.2081
#   Average l_d: -0.6938
#   Average l_nd: -0.4857
#
# yy
# breaking
# 100
# Finished epoch 3: 315.109s
#   Average loss: 0.2209
#   Average l_n: 0.2110
#   Average l_d: -0.6975
#   Average l_nd: -0.4865
#
# yy
# breaking
# 100
# Finished epoch 4: 420.037s
#   Average loss: 0.2201
#   Average l_n: 0.2078
#   Average l_d: -0.6927
#   Average l_nd: -0.4850
#
# yy
# breaking
# 100
# Finished epoch 5: 524.770s
#   Average loss: 0.2188
#   Average l_n: 0.2079
#   Average l_d: -0.6974
#   Average l_nd: -0.4895
#
# lr: 0.001, beta1: 0.5, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 105.076s
#   Average loss: 0.2189
#   Average l_n: 0.2003
#   Average l_d: -0.6751
#   Average l_nd: -0.4747
#
# yy
# breaking
# 100
# Finished epoch 2: 210.521s
#   Average loss: 0.2157
#   Average l_n: 0.2083
#   Average l_d: -0.6946
#   Average l_nd: -0.4864
#
# yy
# breaking
# 100
# Finished epoch 3: 315.141s
#   Average loss: 0.2158
#   Average l_n: 0.2037
#   Average l_d: -0.6879
#   Average l_nd: -0.4841
#
# yy
# breaking
# 100
# Finished epoch 4: 419.846s
#   Average loss: 0.2179
#   Average l_n: 0.2088
#   Average l_d: -0.6878
#   Average l_nd: -0.4790
#
# yy
# breaking
# 100
# Finished epoch 5: 524.369s
#   Average loss: 0.2155
#   Average l_n: 0.2045
#   Average l_d: -0.6835
#   Average l_nd: -0.4790
#
# lr: 0.001, beta1: 0.6, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 105.209s
#   Average loss: 0.2138
#   Average l_n: 0.2042
#   Average l_d: -0.6853
#   Average l_nd: -0.4812
#
# yy
# breaking
# 100
# Finished epoch 2: 210.320s
#   Average loss: 0.2141
#   Average l_n: 0.2035
#   Average l_d: -0.6875
#   Average l_nd: -0.4840
#
# yy
# breaking
# 100
# Finished epoch 4: 418.150s
#   Average loss: 0.2076
#   Average l_n: 0.1958
#   Average l_d: -0.6843
#   Average l_nd: -0.4884
#
# yy
# breaking
# 100
# Finished epoch 5: 522.545s
#   Average loss: 0.2173
#   Average l_n: 0.2049
#   Average l_d: -0.6801
#   Average l_nd: -0.4753
#
# lr: 0.001, beta1: 0.7, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 103.792s
#   Average loss: 0.2104
#   Average l_n: 0.1966
#   Average l_d: -0.6799
#   Average l_nd: -0.4834
#
# yy
# breaking
# 100
# Finished epoch 2: 207.588s
#   Average loss: 0.2108
#   Average l_n: 0.1967
#   Average l_d: -0.6767
#   Average l_nd: -0.4801
#
# yy
# breaking
# 100
# Finished epoch 3: 312.033s
#   Average loss: 0.2113
#   Average l_n: 0.2038
#   Average l_d: -0.6837
#   Average l_nd: -0.4799
#
# yy
# breaking
# 100
# Finished epoch 4: 416.001s
#   Average loss: 0.2097
#   Average l_n: 0.2000
#   Average l_d: -0.6806
#   Average l_nd: -0.4806
#
# yy
# breaking
# 100
# Finished epoch 5: 519.742s
#   Average loss: 0.2124
#   Average l_n: 0.2000
#   Average l_d: -0.6746
#   Average l_nd: -0.4747
#
# lr: 0.001, beta1: 0.8, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 103.866s
#   Average loss: 0.2094
#   Average l_n: 0.1994
#   Average l_d: -0.6838
#   Average l_nd: -0.4845
#
# yy
# breaking
# 100
# Finished epoch 2: 208.189s
#   Average loss: 0.2078
#   Average l_n: 0.1988
#   Average l_d: -0.6845
#   Average l_nd: -0.4858
#
# yy
# breaking
# 100
# Finished epoch 3: 312.085s
#   Average loss: 0.2084
#   Average l_n: 0.1973
#   Average l_d: -0.6823
#   Average l_nd: -0.4849
#
# yy
# breaking
# 100
# Finished epoch 4: 415.743s
#   Average loss: 0.2095
#   Average l_n: 0.1999
#   Average l_d: -0.6801
#   Average l_nd: -0.4802
#
# yy
# breaking
# 100
# Finished epoch 5: 519.910s
#   Average loss: 0.2085
#   Average l_n: 0.1964
#   Average l_d: -0.6771
#   Average l_nd: -0.4807
#
# lr: 0.001, beta1: 0.9, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 104.287s
#   Average loss: 0.2101
#   Average l_n: 0.1980
#   Average l_d: -0.6773
#   Average l_nd: -0.4793
#
# yy
# breaking
# 100
# Finished epoch 2: 267.681s
#   Average loss: 0.2090
#   Average l_n: 0.2001
#   Average l_d: -0.6809
#   Average l_nd: -0.4809
#
# yy
# breaking
# 100
# Finished epoch 3: 487.252s
#   Average loss: 0.2095
#   Average l_n: 0.1973
#   Average l_d: -0.6781
#   Average l_nd: -0.4808
#
# yy
# breaking
# 100
# Finished epoch 4: 704.515s
#   Average loss: 0.2111
#   Average l_n: 0.2004
#   Average l_d: -0.6775
#   Average l_nd: -0.4771
#
# yy
# breaking
# 100
# Finished epoch 5: 924.208s
#   Average loss: 0.2120
#   Average l_n: 0.2034
#   Average l_d: -0.6811
#   Average l_nd: -0.4777
#
# lr: 0.003, beta1: 0.5, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 216.583s
#   Average loss: 0.2077
#   Average l_n: 0.1951
#   Average l_d: -0.6785
#   Average l_nd: -0.4834
#
# yy
# breaking
# 100
# Finished epoch 2: 434.673s
#   Average loss: 0.2132
#   Average l_n: 0.2043
#   Average l_d: -0.6831
#   Average l_nd: -0.4788
#
# yy
# breaking
# 100
# Finished epoch 3: 651.345s
#   Average loss: 0.2110
#   Average l_n: 0.1991
#   Average l_d: -0.6804
#   Average l_nd: -0.4813
#
# yy
# breaking
# 100
# Finished epoch 4: 865.617s
#   Average loss: 0.2118
#   Average l_n: 0.2044
#   Average l_d: -0.6829
#   Average l_nd: -0.4786
#
# yy
# breaking
# 100
# Finished epoch 5: 1083.085s
#   Average loss: 0.2123
#   Average l_n: 0.1999
#   Average l_d: -0.6789
#   Average l_nd: -0.4789
#
# lr: 0.003, beta1: 0.6, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 218.922s
#   Average loss: 0.2054
#   Average l_n: 0.1988
#   Average l_d: -0.6887
#   Average l_nd: -0.4899
#
# yy
# breaking
# 100
# Finished epoch 2: 441.910s
#   Average loss: 0.2075
#   Average l_n: 0.2004
#   Average l_d: -0.6854
#   Average l_nd: -0.4850
#
# yy
# breaking
# 100
# Finished epoch 4: 877.619s
#   Average loss: 0.2098
#   Average l_n: 0.1982
#   Average l_d: -0.6735
#   Average l_nd: -0.4752
#
# yy
# breaking
# 100
# Finished epoch 5: 1100.101s
#   Average loss: 0.2143
#   Average l_n: 0.2047
#   Average l_d: -0.6808
#   Average l_nd: -0.4762
#
# lr: 0.003, beta1: 0.7, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 219.897s
#   Average loss: 0.2079
#   Average l_n: 0.1972
#   Average l_d: -0.6758
#   Average l_nd: -0.4786
#
# yy
# breaking
# 100
# Finished epoch 2: 437.110s
#   Average loss: 0.2108
#   Average l_n: 0.2003
#   Average l_d: -0.6753
#   Average l_nd: -0.4750
#
# yy
# breaking
# 100
# Finished epoch 3: 656.020s
#   Average loss: 0.2068
#   Average l_n: 0.1967
#   Average l_d: -0.6811
#   Average l_nd: -0.4845
#
# yy
# breaking
# 100
# Finished epoch 4: 874.065s
#   Average loss: 0.2077
#   Average l_n: 0.1953
#   Average l_d: -0.6755
#   Average l_nd: -0.4802
#
# yy
# breaking
# 100
# Finished epoch 5: 1093.113s
#   Average loss: 0.2050
#   Average l_n: 0.1917
#   Average l_d: -0.6759
#   Average l_nd: -0.4842
#
# lr: 0.003, beta1: 0.8, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 216.940s
#   Average loss: 0.2078
#   Average l_n: 0.1908
#   Average l_d: -0.6675
#   Average l_nd: -0.4767
#
# yy
# breaking
# 100
# Finished epoch 2: 432.344s
#   Average loss: 0.2065
#   Average l_n: 0.1980
#   Average l_d: -0.6836
#   Average l_nd: -0.4855
#
# yy
# Finished epoch 3: 652.906s
#   Average loss: 0.2097
#   Average l_n: 0.1971
#   Average l_d: -0.6724
#   Average l_nd: -0.4753
#
# yy
# breaking
# 100
# Finished epoch 4: 869.302s
#   Average loss: 0.2059
#   Average l_n: 0.1930
#   Average l_d: -0.6756
#   Average l_nd: -0.4826
#
# yy
# breaking
# 100
# Finished epoch 5: 1087.891s
#   Average loss: 0.2063
#   Average l_n: 0.1954
#   Average l_d: -0.6790
#   Average l_nd: -0.4837
#
# lr: 0.003, beta1: 0.9, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 221.543s
#   Average loss: 0.2076
#   Average l_n: 0.1917
#   Average l_d: -0.6665
#   Average l_nd: -0.4748
#
# yy
# breaking
# 100
# Finished epoch 2: 444.565s
#   Average loss: 0.2066
#   Average l_n: 0.1952
#   Average l_d: -0.6741
#   Average l_nd: -0.4789
#
# yy
# breaking
# 100
# Finished epoch 3: 665.205s
#   Average loss: 0.2038
#   Average l_n: 0.1899
#   Average l_d: -0.6755
#   Average l_nd: -0.4856
#
# yy
# breaking
# 100
# Finished epoch 4: 881.410s
#   Average loss: 0.2040
#   Average l_n: 0.1920
#   Average l_d: -0.6728
#   Average l_nd: -0.4808
#
# yy
# breaking
# 100
# Finished epoch 5: 1098.782s
#   Average loss: 0.2071
#   Average l_n: 0.1938
#   Average l_d: -0.6750
#   Average l_nd: -0.4811
#
# lr: 0.0001, beta1: 0.5, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 218.926s
#   Average loss: 0.2024
#   Average l_n: 0.1926
#   Average l_d: -0.6751
#   Average l_nd: -0.4825
#
# yy
# breaking
# 100
# Finished epoch 2: 435.730s
#   Average loss: 0.2052
#   Average l_n: 0.1954
#   Average l_d: -0.6785
#   Average l_nd: -0.4831
#
# yy
# breaking
# 100
# Finished epoch 3: 654.835s
#   Average loss: 0.2060
#   Average l_n: 0.1943
#   Average l_d: -0.6772
#   Average l_nd: -0.4828
#
# yy
# breaking
# 100
# Finished epoch 4: 873.301s
#   Average loss: 0.2056
#   Average l_n: 0.1941
#   Average l_d: -0.6750
#   Average l_nd: -0.4809
#
# yy
# breaking
# 100
# Finished epoch 5: 1094.677s
#   Average loss: 0.2051
#   Average l_n: 0.1918
#   Average l_d: -0.6751
#   Average l_nd: -0.4833
#
# lr: 0.0001, beta1: 0.6, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 218.567s
#   Average loss: 0.2030
#   Average l_n: 0.1910
#   Average l_d: -0.6768
#   Average l_nd: -0.4859
#
# yy
# breaking
# 100
# Finished epoch 2: 438.198s
#   Average loss: 0.2045
#   Average l_n: 0.1924
#   Average l_d: -0.6751
#   Average l_nd: -0.4826
#
# yy
# breaking
# 100
# Finished epoch 3: 656.417s
#   Average loss: 0.2050
#   Average l_n: 0.1946
#   Average l_d: -0.6771
#   Average l_nd: -0.4825
#
# yy
# breaking
# 100
# Finished epoch 4: 870.558s
#   Average loss: 0.2047
#   Average l_n: 0.1933
#   Average l_d: -0.6771
#   Average l_nd: -0.4838
#
# yy
# breaking
# 100
# Finished epoch 5: 1093.818s
#   Average loss: 0.2046
#   Average l_n: 0.1938
#   Average l_d: -0.6762
#   Average l_nd: -0.4824
#
# lr: 0.0001, beta1: 0.7, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 220.014s
#   Average loss: 0.2054
#   Average l_n: 0.1944
#   Average l_d: -0.6765
#   Average l_nd: -0.4821
#
# yy
# breaking
# 100
# Finished epoch 3: 659.112s
#   Average loss: 0.2050
#   Average l_n: 0.1910
#   Average l_d: -0.6715
#   Average l_nd: -0.4805
#
# yy
# breaking
# 100
# Finished epoch 4: 878.778s
#   Average loss: 0.2076
#   Average l_n: 0.1931
#   Average l_d: -0.6710
#   Average l_nd: -0.4778
#
# yy
# breaking
# 100
# Finished epoch 5: 1099.173s
#   Average loss: 0.2049
#   Average l_n: 0.1962
#   Average l_d: -0.6785
#   Average l_nd: -0.4824
#
# lr: 0.0001, beta1: 0.8, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 220.551s
#   Average loss: 0.2056
#   Average l_n: 0.1935
#   Average l_d: -0.6761
#   Average l_nd: -0.4826
#
# yy
# breaking
# 100
# Finished epoch 2: 443.986s
#   Average loss: 0.2062
#   Average l_n: 0.1931
#   Average l_d: -0.6707
#   Average l_nd: -0.4776
#
# yy
# breaking
# 100
# Finished epoch 3: 662.477s
#   Average loss: 0.2067
#   Average l_n: 0.1984
#   Average l_d: -0.6762
#   Average l_nd: -0.4779
#
# yy
# breaking
# 100
# Finished epoch 4: 881.382s
#   Average loss: 0.2037
#   Average l_n: 0.1919
#   Average l_d: -0.6740
#   Average l_nd: -0.4821
#
# yy
# breaking
# 100
# Finished epoch 5: 1099.451s
#   Average loss: 0.2065
#   Average l_n: 0.1959
#   Average l_d: -0.6764
#   Average l_nd: -0.4805
#
# lr: 0.0001, beta1: 0.9, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 217.969s
#   Average loss: 0.2070
#   Average l_n: 0.1965
#   Average l_d: -0.6736
#   Average l_nd: -0.4771
#
# yy
# breaking
# 100
# Finished epoch 2: 434.189s
#   Average loss: 0.2083
#   Average l_n: 0.1975
#   Average l_d: -0.6737
#   Average l_nd: -0.4761
#
# yy
# breaking
# 100
# Finished epoch 3: 652.784s
#   Average loss: 0.2029
#   Average l_n: 0.1927
#   Average l_d: -0.6791
#   Average l_nd: -0.4864
#
# yy
# breaking
# 100
# Finished epoch 4: 871.425s
#   Average loss: 0.2070
#   Average l_n: 0.1945
#   Average l_d: -0.6736
#   Average l_nd: -0.4791
#
# yy
# breaking
# 100
# Finished epoch 5: 1088.116s
#   Average loss: 0.2052
#   Average l_n: 0.1951
#   Average l_d: -0.6776
#   Average l_nd: -0.4825
#
# lr: 0.0003, beta1: 0.5, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 220.066s
#   Average loss: 0.2035
#   Average l_n: 0.1942
#   Average l_d: -0.6795
#   Average l_nd: -0.4854
#
# yy
# breaking
# 100
# Finished epoch 2: 439.021s
#   Average loss: 0.2054
#   Average l_n: 0.1948
#   Average l_d: -0.6769
#   Average l_nd: -0.4821
#
# yy
# breaking
# 100
# Finished epoch 3: 657.368s
#   Average loss: 0.2052
#   Average l_n: 0.1924
#   Average l_d: -0.6724
#   Average l_nd: -0.4799
#
# yy
# breaking
# 100
# Finished epoch 4: 876.725s
#   Average loss: 0.2009
#   Average l_n: 0.1917
#   Average l_d: -0.6796
#   Average l_nd: -0.4879
#
# yy
# breaking
# 100
# Finished epoch 5: 1096.924s
#   Average loss: 0.2052
#   Average l_n: 0.1947
#   Average l_d: -0.6753
#   Average l_nd: -0.4806
#
# lr: 0.0003, beta1: 0.6, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 220.008s
#   Average loss: 0.2039
#   Average l_n: 0.1923
#   Average l_d: -0.6720
#   Average l_nd: -0.4797
#
# yy
# breaking
# 100
# Finished epoch 2: 439.840s
#   Average loss: 0.2003
#   Average l_n: 0.1901
#   Average l_d: -0.6787
#   Average l_nd: -0.4886
#
# yy
# breaking
# 100
# Finished epoch 3: 658.304s
#   Average loss: 0.2048
#   Average l_n: 0.1962
#   Average l_d: -0.6790
#   Average l_nd: -0.4829
#
# yy
# breaking
# 100
# Finished epoch 4: 877.555s
#   Average loss: 0.2028
#   Average l_n: 0.1926
#   Average l_d: -0.6741
#   Average l_nd: -0.4815
#
# yy
# breaking
# 100
# Finished epoch 5: 1096.166s
#   Average loss: 0.2020
#   Average l_n: 0.1911
#   Average l_d: -0.6762
#   Average l_nd: -0.4852
#
# lr: 0.0003, beta1: 0.7, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 220.964s
#   Average loss: 0.2046
#   Average l_n: 0.1934
#   Average l_d: -0.6729
#   Average l_nd: -0.4795
#
# yy
# breaking
# 100
# Finished epoch 2: 441.067s
#   Average loss: 0.2022
#   Average l_n: 0.1908
#   Average l_d: -0.6732
#   Average l_nd: -0.4824
#
# yy
# breaking
# 100
# Finished epoch 3: 662.443s
#   Average loss: 0.2047
#   Average l_n: 0.1952
#   Average l_d: -0.6767
#   Average l_nd: -0.4814
#
# yy
# breaking
# 100
# Finished epoch 4: 885.089s
#   Average loss: 0.2015
#   Average l_n: 0.1903
#   Average l_d: -0.6778
#   Average l_nd: -0.4875
#
# yy
# breaking
# 100
# Finished epoch 5: 1107.895s
#   Average loss: 0.2059
#   Average l_n: 0.1969
#   Average l_d: -0.6765
#   Average l_nd: -0.4797
#
# lr: 0.0003, beta1: 0.8, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 223.263s
#   Average loss: 0.2065
#   Average l_n: 0.1957
#   Average l_d: -0.6756
#   Average l_nd: -0.4800
#
# yy
# breaking
# 100
# Finished epoch 2: 447.504s
#   Average loss: 0.2039
#   Average l_n: 0.1933
#   Average l_d: -0.6792
#   Average l_nd: -0.4859
#
# yy
# breaking
# 100
# Finished epoch 3: 669.911s
#   Average loss: 0.2060
#   Average l_n: 0.1974
#   Average l_d: -0.6784
#   Average l_nd: -0.4811
#
# yy
# breaking
# 100
# Finished epoch 5: 1118.977s
#   Average loss: 0.2086
#   Average l_n: 0.1989
#   Average l_d: -0.6793
#   Average l_nd: -0.4805
#
# lr: 0.0003, beta1: 0.9, margin: 10
# yy
# breaking
# 100
# Finished epoch 1: 226.529s
#   Average loss: 0.2048
#   Average l_n: 0.1946
#   Average l_d: -0.6796
#   Average l_nd: -0.4851
#
# yy
# breaking
# 100
# Finished epoch 2: 458.412s
#   Average loss: 0.2054
#   Average l_n: 0.1955
#   Average l_d: -0.6783
#   Average l_nd: -0.4827
#
# yy
# breaking
# 100
# Finished epoch 3: 683.260s
#   Average loss: 0.2044
#   Average l_n: 0.1936
#   Average l_d: -0.6770
#   Average l_nd: -0.4834
#
# yy
# breaking
# 100
# Finished epoch 4: 910.665s
#   Average loss: 0.2038
#   Average l_n: 0.1943
#   Average l_d: -0.6810
#   Average l_nd: -0.4868
#
# yy
# breaking
# 100
# Finished epoch 5: 1136.508s
#   Average loss: 0.2007
#   Average l_n: 0.1877
#   Average l_d: -0.6760
#   Average l_nd: -0.4883
#
# lr: 0.01, beta1: 0.5, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 224.825s
#   Average loss: 0.3161
#   Average l_n: 0.2688
#   Average l_d: -0.9597
#   Average l_nd: -0.6909
#
# yy
# breaking
# 100
# Finished epoch 2: 452.616s
#   Average loss: 0.3188
#   Average l_n: 0.2853
#   Average l_d: -0.9915
#   Average l_nd: -0.7062
#
# yy
# breaking
# 100
# Finished epoch 3: 679.173s
#   Average loss: 0.3132
#   Average l_n: 0.2881
#   Average l_d: -1.0153
#   Average l_nd: -0.7272
#
# yy
# breaking
# 100
# Finished epoch 4: 905.591s
#   Average loss: 0.3138
#   Average l_n: 0.2782
#   Average l_d: -0.9926
#   Average l_nd: -0.7144
#
# yy
# breaking
# 100
# Finished epoch 5: 1132.735s
#   Average loss: 0.3101
#   Average l_n: 0.2863
#   Average l_d: -1.0163
#   Average l_nd: -0.7300
#
# lr: 0.01, beta1: 0.6, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 228.680s
#   Average loss: 0.3027
#   Average l_n: 0.2799
#   Average l_d: -1.0189
#   Average l_nd: -0.7391
#
# yy
# breaking
# 100
# Finished epoch 2: 455.681s
#   Average loss: 0.3043
#   Average l_n: 0.2747
#   Average l_d: -1.0036
#   Average l_nd: -0.7289
#
# yy
# breaking
# 100
# Finished epoch 3: 682.514s
#   Average loss: 0.3071
#   Average l_n: 0.2860
#   Average l_d: -1.0186
#   Average l_nd: -0.7326
#
# yy
# breaking
# 100
# Finished epoch 4: 910.210s
#   Average loss: 0.3136
#   Average l_n: 0.2900
#   Average l_d: -1.0129
#   Average l_nd: -0.7229
#
# yy
# breaking
# 100
# Finished epoch 5: 1132.565s
#   Average loss: 0.3149
#   Average l_n: 0.2928
#   Average l_d: -1.0129
#   Average l_nd: -0.7201
#
# lr: 0.01, beta1: 0.7, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 228.387s
#   Average loss: 0.3070
#   Average l_n: 0.2914
#   Average l_d: -1.0263
#   Average l_nd: -0.7349
#
# yy
# breaking
# 100
# Finished epoch 2: 455.976s
#   Average loss: 0.3172
#   Average l_n: 0.2895
#   Average l_d: -1.0027
#   Average l_nd: -0.7132
#
# yy
# breaking
# breaking
# 100
# Finished epoch 4: 910.118s
#   Average loss: 0.3109
#   Average l_n: 0.2890
#   Average l_d: -1.0114
#   Average l_nd: -0.7225
#
# yy
# breaking
# 100
# Finished epoch 5: 1137.420s
#   Average loss: 0.3099
#   Average l_n: 0.2831
#   Average l_d: -1.0041
#   Average l_nd: -0.7210
#
# lr: 0.01, beta1: 0.8, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 225.792s
#   Average loss: 0.3041
#   Average l_n: 0.2812
#   Average l_d: -1.0114
#   Average l_nd: -0.7301
#
# yy
# breaking
# 100
# Finished epoch 2: 450.459s
#   Average loss: 0.3075
#   Average l_n: 0.2846
#   Average l_d: -1.0070
#   Average l_nd: -0.7224
#
# yy
# breaking
# 100
# Finished epoch 3: 674.432s
#   Average loss: 0.3033
#   Average l_n: 0.2769
#   Average l_d: -1.0059
#   Average l_nd: -0.7290
#
# yy
# breaking
# 100
# Finished epoch 4: 899.415s
#   Average loss: 0.3063
#   Average l_n: 0.2798
#   Average l_d: -1.0022
#   Average l_nd: -0.7223
#
# yy
# breaking
# 100
# Finished epoch 5: 1124.923s
#   Average loss: 0.3085
#   Average l_n: 0.2776
#   Average l_d: -0.9932
#   Average l_nd: -0.7156
#
# lr: 0.01, beta1: 0.9, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 226.043s
#   Average loss: 0.3045
#   Average l_n: 0.2783
#   Average l_d: -1.0039
#   Average l_nd: -0.7256
#
# yy
# breaking
# 100
# Finished epoch 2: 449.166s
#   Average loss: 0.3049
#   Average l_n: 0.2831
#   Average l_d: -1.0147
#   Average l_nd: -0.7316
#
# yy
# breaking
# 100
# Finished epoch 3: 674.121s
#   Average loss: 0.3096
#   Average l_n: 0.2880
#   Average l_d: -1.0171
#   Average l_nd: -0.7290
#
# yy
# breaking
# 100
# Finished epoch 4: 898.951s
#   Average loss: 0.3088
#   Average l_n: 0.2880
#   Average l_d: -1.0160
#   Average l_nd: -0.7280
#
# yy
# breaking
# 100
# Finished epoch 5: 1122.203s
#   Average loss: 0.3020
#   Average l_n: 0.2751
#   Average l_d: -1.0036
#   Average l_nd: -0.7285
#
# lr: 0.03, beta1: 0.5, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 220.852s
#   Average loss: 0.3221
#   Average l_n: 0.3072
#   Average l_d: -1.0421
#   Average l_nd: -0.7349
#
# yy
# breaking
# 100
# Finished epoch 2: 443.291s
#   Average loss: 0.3146
#   Average l_n: 0.2896
#   Average l_d: -1.0224
#   Average l_nd: -0.7328
#
# yy
# breaking
# 100
# Finished epoch 3: 666.704s
#   Average loss: 0.3170
#   Average l_n: 0.2938
#   Average l_d: -1.0261
#   Average l_nd: -0.7323
#
# yy
# breaking
# 100
# Finished epoch 4: 888.818s
#   Average loss: 0.3239
#   Average l_n: 0.3035
#   Average l_d: -1.0297
#   Average l_nd: -0.7262
#
# yy
# breaking
# 100
# Finished epoch 5: 1117.471s
#   Average loss: 0.3177
#   Average l_n: 0.3003
#   Average l_d: -1.0360
#   Average l_nd: -0.7357
#
# lr: 0.03, beta1: 0.6, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 228.200s
#   Average loss: 0.3239
#   Average l_n: 0.3023
#   Average l_d: -1.0269
#   Average l_nd: -0.7246
#
# yy
# breaking
# 100
# Finished epoch 2: 472.384s
#   Average loss: 0.3147
#   Average l_n: 0.2887
#   Average l_d: -1.0243
#   Average l_nd: -0.7355
# yy
# breaking
# 100
# Finished epoch 3: 704.209s
#   Average loss: 0.3147
#   Average l_n: 0.2892
#   Average l_d: -1.0210
#   Average l_nd: -0.7318
#
# yy
# breaking
# 100
# Finished epoch 4: 929.101s
#   Average loss: 0.3202
#   Average l_n: 0.2965
#   Average l_d: -1.0272
#   Average l_nd: -0.7306
#
# yy
# breaking
# 100
# Finished epoch 5: 1151.725s
#   Average loss: 0.3166
#   Average l_n: 0.2953
#   Average l_d: -1.0293
#   Average l_nd: -0.7340
#
# lr: 0.03, beta1: 0.7, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 229.729s
#   Average loss: 0.3137
#   Average l_n: 0.2935
#   Average l_d: -1.0291
#   Average l_nd: -0.7356
#
# yy
# breaking
# 100
# Finished epoch 2: 454.544s
#   Average loss: 0.3148
#   Average l_n: 0.2979
#   Average l_d: -1.0396
#   Average l_nd: -0.7416
#
# yy
# breaking
# 100
# Finished epoch 3: 682.031s
#   Average loss: 0.3158
#   Average l_n: 0.2968
#   Average l_d: -1.0301
#   Average l_nd: -0.7333
#
# yy
# breaking
# 100
# Finished epoch 4: 905.951s
#   Average loss: 0.3127
#   Average l_n: 0.3002
#   Average l_d: -1.0410
#   Average l_nd: -0.7408
#
# yy
# breaking
# 100
# Finished epoch 5: 1128.435s
#   Average loss: 0.3127
#   Average l_n: 0.2948
#   Average l_d: -1.0286
#   Average l_nd: -0.7338
#
# lr: 0.03, beta1: 0.8, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 221.484s
#   Average loss: 0.3112
#   Average l_n: 0.2888
#   Average l_d: -1.0238
#   Average l_nd: -0.7350
#
# yy
# breaking
# 100
# Finished epoch 2: 443.102s
#   Average loss: 0.3094
#   Average l_n: 0.2943
#   Average l_d: -1.0315
#   Average l_nd: -0.7372
#
# yy
# breaking
# 100
# Finished epoch 3: 665.907s
#   Average loss: 0.3160
#   Average l_n: 0.2936
#   Average l_d: -1.0290
#   Average l_nd: -0.7353
#
# yy
# breaking
# 100
# Finished epoch 4: 891.898s
#   Average loss: 0.3140
#   Average l_n: 0.2963
#   Average l_d: -1.0342
#   Average l_nd: -0.7380
#
# yy
# breaking
# 100
# Finished epoch 5: 1115.378s
#   Average loss: 0.3128
#   Average l_n: 0.2965
#   Average l_d: -1.0316
#   Average l_nd: -0.7351
#
# lr: 0.03, beta1: 0.9, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 223.771s
#   Average loss: 0.3119
#   Average l_n: 0.2903
#   Average l_d: -1.0274
#   Average l_nd: -0.7371
#
# yy
# breaking
# 100
# Finished epoch 2: 446.053s
#   Average loss: 0.3142
#   Average l_n: 0.2979
#   Average l_d: -1.0307
#   Average l_nd: -0.7328
#
# yy
# breaking
# 100
# Finished epoch 3: 670.917s
#   Average loss: 0.3099
#   Average l_n: 0.2935
#   Average l_d: -1.0334
#   Average l_nd: -0.7399
#
# yy
# breaking
# 100
# Finished epoch 4: 892.603s
#   Average loss: 0.3155
#   Average l_n: 0.2986
#   Average l_d: -1.0366
#   Average l_nd: -0.7380
#
# yy
# breaking
# 100
# Finished epoch 5: 1114.151s
#   Average loss: 0.3110
#   Average l_n: 0.2893
#   Average l_d: -1.0206
#   Average l_nd: -0.7313
#
# lr: 0.001, beta1: 0.5, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 223.400s
#   Average loss: 0.3088
#   Average l_n: 0.3037
#   Average l_d: -1.0744
#   Average l_nd: -0.7708
#
# yy
# breaking
# 100
# Finished epoch 2: 445.582s
#   Average loss: 0.3030
#   Average l_n: 0.2862
#   Average l_d: -1.0318
#   Average l_nd: -0.7456
#
# yy
# breaking
# 100
# Finished epoch 3: 665.106s
#   Average loss: 0.3030
#   Average l_n: 0.2842
#   Average l_d: -1.0200
#   Average l_nd: -0.7358
#
# yy
# breaking
# 100
# Finished epoch 4: 887.174s
#   Average loss: 0.3031
#   Average l_n: 0.2838
#   Average l_d: -1.0143
#   Average l_nd: -0.7304
#
# yy
# breaking
# 100
# Finished epoch 5: 1110.032s
#   Average loss: 0.3016
#   Average l_n: 0.2800
#   Average l_d: -1.0106
#   Average l_nd: -0.7305
#
# lr: 0.001, beta1: 0.6, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 223.989s
#   Average loss: 0.2978
#   Average l_n: 0.2789
#   Average l_d: -1.0151
#   Average l_nd: -0.7363
#
# yy
# breaking
# 100
# Finished epoch 2: 443.366s
#   Average loss: 0.3016
#   Average l_n: 0.2787
#   Average l_d: -1.0094
#   Average l_nd: -0.7307
#
# yy
# breaking
# 100
# Finished epoch 3: 666.420s
#   Average loss: 0.2988
#   Average l_n: 0.2808
#   Average l_d: -1.0156
#   Average l_nd: -0.7348
#
# yy
# breaking
# 100
# Finished epoch 4: 888.824s
#   Average loss: 0.2975
#   Average l_n: 0.2756
#   Average l_d: -1.0072
#   Average l_nd: -0.7316
#
# yy
# breaking
# 100
# Finished epoch 5: 1111.014s
#   Average loss: 0.2987
#   Average l_n: 0.2732
#   Average l_d: -1.0056
#   Average l_nd: -0.7325
#
# lr: 0.001, beta1: 0.7, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 222.776s
#   Average loss: 0.2935
#   Average l_n: 0.2724
#   Average l_d: -1.0076
#   Average l_nd: -0.7352
#
# yy
# breaking
# 100
# Finished epoch 2: 443.418s
#   Average loss: 0.3039
#   Average l_n: 0.2790
#   Average l_d: -1.0054
#   Average l_nd: -0.7264
#
# yy
# breaking
# 100
# Finished epoch 3: 660.029s
#   Average loss: 0.3017
#   Average l_n: 0.2739
#   Average l_d: -1.0053
#   Average l_nd: -0.7314
#
# yy
# breaking
# 100
# Finished epoch 4: 881.157s
#   Average loss: 0.3044
#   Average l_n: 0.2846
#   Average l_d: -1.0094
#   Average l_nd: -0.7248
#
# yy
# breaking
# 100
# Finished epoch 5: 1102.774s
#   Average loss: 0.2970
#   Average l_n: 0.2724
#   Average l_d: -1.0062
#   Average l_nd: -0.7337
#
# lr: 0.001, beta1: 0.8, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 220.399s
#   Average loss: 0.2982
#   Average l_n: 0.2766
#   Average l_d: -1.0056
#   Average l_nd: -0.7290
#
# yy
# breaking
# 100
# Finished epoch 2: 442.625s
#   Average loss: 0.2961
#   Average l_n: 0.2749
#   Average l_d: -1.0130
#   Average l_nd: -0.7380
#
# yy
# breaking
# 100
# Finished epoch 3: 665.049s
#   Average loss: 0.2939
#   Average l_n: 0.2669
#   Average l_d: -1.0049
#   Average l_nd: -0.7380
#
# yy
# breaking
# 100
# Finished epoch 4: 885.161s
#   Average loss: 0.2907
#   Average l_n: 0.2721
#   Average l_d: -1.0110
#   Average l_nd: -0.7389
#
# yy
# breaking
# 100
# Finished epoch 5: 1105.697s
#   Average loss: 0.2945
#   Average l_n: 0.2709
#   Average l_d: -1.0041
#   Average l_nd: -0.7332
#
# lr: 0.001, beta1: 0.9, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 223.733s
#   Average loss: 0.2981
#   Average l_n: 0.2724
#   Average l_d: -0.9953
#   Average l_nd: -0.7229
#
# yy
# breaking
# 100
# Finished epoch 2: 445.867s
#   Average loss: 0.2938
#   Average l_n: 0.2677
#   Average l_d: -1.0028
#   Average l_nd: -0.7351
#
# yy
# breaking
# 100
# Finished epoch 3: 667.077s
#   Average loss: 0.2957
#   Average l_n: 0.2715
#   Average l_d: -1.0065
#   Average l_nd: -0.7350
#
# yy
# breaking
# 100
# Finished epoch 4: 888.159s
#   Average loss: 0.2875
#   Average l_n: 0.2619
#   Average l_d: -1.0028
#   Average l_nd: -0.7410
#
# yy
# breaking
# 100
# Finished epoch 5: 1110.617s
#   Average loss: 0.2953
#   Average l_n: 0.2726
#   Average l_d: -1.0014
#   Average l_nd: -0.7288
#
# lr: 0.003, beta1: 0.5, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 220.300s
#   Average loss: 0.2980
#   Average l_n: 0.2755
#   Average l_d: -1.0039
#   Average l_nd: -0.7285
#
# yy
# breaking
# 100
# Finished epoch 2: 442.391s
#   Average loss: 0.2965
#   Average l_n: 0.2747
#   Average l_d: -1.0070
#   Average l_nd: -0.7323
#
# yy
# breaking
# 100
# Finished epoch 3: 669.284s
#   Average loss: 0.2882
#   Average l_n: 0.2604
#   Average l_d: -0.9957
#   Average l_nd: -0.7353
#
# yy
# breaking
# 100
# Finished epoch 4: 887.385s
#   Average loss: 0.2942
#   Average l_n: 0.2713
#   Average l_d: -1.0017
#   Average l_nd: -0.7304
#
# yy
# breaking
# 100
# Finished epoch 5: 1108.927s
#   Average loss: 0.2969
#   Average l_n: 0.2745
#   Average l_d: -1.0020
#   Average l_nd: -0.7275
#
# lr: 0.003, beta1: 0.6, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 221.141s
#   Average loss: 0.2973
#   Average l_n: 0.2752
#   Average l_d: -1.0055
#   Average l_nd: -0.7303
#
# yy
# breaking
# 100
# Finished epoch 2: 441.948s
#   Average loss: 0.3001
#   Average l_n: 0.2742
#   Average l_d: -0.9954
#   Average l_nd: -0.7212
#
# yy
# breaking
# 100
# Finished epoch 3: 666.362s
#   Average loss: 0.2981
#   Average l_n: 0.2693
#   Average l_d: -0.9915
#   Average l_nd: -0.7222
#
# yy
# breaking
# 100
# Finished epoch 4: 890.048s
#   Average loss: 0.2884
#   Average l_n: 0.2651
#   Average l_d: -1.0004
#   Average l_nd: -0.7353
#
# yy
# breaking
# 100
# Finished epoch 5: 1109.789s
#   Average loss: 0.2978
#   Average l_n: 0.2703
#   Average l_d: -0.9923
#   Average l_nd: -0.7220
#
# lr: 0.003, beta1: 0.7, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 220.347s
#   Average loss: 0.2878
#   Average l_n: 0.2584
#   Average l_d: -0.9913
#   Average l_nd: -0.7329
#
# yy
# breaking
# 100
# Finished epoch 2: 441.655s
#   Average loss: 0.2951
#   Average l_n: 0.2671
#   Average l_d: -0.9957
#   Average l_nd: -0.7287
#
# yy
# breaking
# 100
# Finished epoch 3: 663.996s
#   Average loss: 0.2872
#   Average l_n: 0.2621
#   Average l_d: -0.9965
#   Average l_nd: -0.7344
#
# yy
# breaking
# 100
# Finished epoch 4: 885.192s
#   Average loss: 0.2961
#   Average l_n: 0.2767
#   Average l_d: -1.0059
#   Average l_nd: -0.7292
#
# yy
# breaking
# 100
# Finished epoch 5: 1109.577s
#   Average loss: 0.2919
#   Average l_n: 0.2695
#   Average l_d: -1.0007
#   Average l_nd: -0.7312
#
# lr: 0.003, beta1: 0.8, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 221.293s
#   Average loss: 0.2962
#   Average l_n: 0.2676
#   Average l_d: -0.9920
#   Average l_nd: -0.7244
#
# yy
# breaking
# 100
# Finished epoch 2: 441.100s
#   Average loss: 0.2919
#   Average l_n: 0.2681
#   Average l_d: -0.9978
#   Average l_nd: -0.7297
#
# yy
# breaking
# 100
# Finished epoch 3: 662.905s
#   Average loss: 0.2990
#   Average l_n: 0.2757
#   Average l_d: -1.0011
#   Average l_nd: -0.7254
#
# yy
# breaking
# 100
# Finished epoch 4: 882.344s
#   Average loss: 0.2956
#   Average l_n: 0.2738
#   Average l_d: -1.0023
#   Average l_nd: -0.7285
#
# yy
# breaking
# 100
# Finished epoch 5: 1101.968s
#   Average loss: 0.2959
#   Average l_n: 0.2691
#   Average l_d: -0.9904
#   Average l_nd: -0.7213
#
# lr: 0.003, beta1: 0.9, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 218.408s
#   Average loss: 0.2930
#   Average l_n: 0.2706
#   Average l_d: -1.0018
#   Average l_nd: -0.7313
#
# yy
# breaking
# 100
# Finished epoch 2: 439.763s
#   Average loss: 0.2978
#   Average l_n: 0.2734
#   Average l_d: -0.9983
#   Average l_nd: -0.7249
#
# yy
# breaking
# 100
# Finished epoch 3: 663.790s
#   Average loss: 0.2910
#   Average l_n: 0.2670
#   Average l_d: -0.9995
#   Average l_nd: -0.7325
#
# yy
# breaking
# 100
# Finished epoch 4: 882.862s
#   Average loss: 0.2895
#   Average l_n: 0.2673
#   Average l_d: -0.9976
#   Average l_nd: -0.7302
#
# yy
# breaking
# 100
# Finished epoch 5: 1101.431s
#   Average loss: 0.2966
#   Average l_n: 0.2663
#   Average l_d: -0.9920
#   Average l_nd: -0.7256
#
# lr: 0.0001, beta1: 0.5, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 219.598s
#   Average loss: 0.2907
#   Average l_n: 0.2675
#   Average l_d: -1.0061
#   Average l_nd: -0.7386
#
# yy
# breaking
# 100
# Finished epoch 2: 440.948s
#   Average loss: 0.2909
#   Average l_n: 0.2659
#   Average l_d: -0.9999
#   Average l_nd: -0.7340
#
# yy
# breaking
# 100
# Finished epoch 3: 663.048s
#   Average loss: 0.2896
#   Average l_n: 0.2681
#   Average l_d: -1.0023
#   Average l_nd: -0.7342
#
# yy
# breaking
# 100
# Finished epoch 4: 883.475s
#   Average loss: 0.2922
#   Average l_n: 0.2704
#   Average l_d: -1.0047
#   Average l_nd: -0.7343
#
# yy
# breaking
# 100
# Finished epoch 5: 1103.800s
#   Average loss: 0.2940
#   Average l_n: 0.2700
#   Average l_d: -1.0018
#   Average l_nd: -0.7317
#
# lr: 0.0001, beta1: 0.6, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 224.407s
#   Average loss: 0.2901
#   Average l_n: 0.2655
#   Average l_d: -1.0005
#   Average l_nd: -0.7350
#
# yy
# breaking
# 100
# Finished epoch 2: 446.541s
#   Average loss: 0.2933
#   Average l_n: 0.2731
#   Average l_d: -1.0075
#   Average l_nd: -0.7343
#
# yy
# breaking
# 100
# Finished epoch 3: 667.782s
#   Average loss: 0.2900
#   Average l_n: 0.2652
#   Average l_d: -0.9989
#   Average l_nd: -0.7336
#
# yy
# breaking
# 100
# Finished epoch 4: 892.675s
#   Average loss: 0.2873
#   Average l_n: 0.2646
#   Average l_d: -1.0045
#   Average l_nd: -0.7400
#
# yy
# breaking
# 100
# Finished epoch 5: 1115.497s
#   Average loss: 0.2897
#   Average l_n: 0.2651
#   Average l_d: -0.9998
#   Average l_nd: -0.7347
#
# lr: 0.0001, beta1: 0.7, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 220.339s
#   Average loss: 0.2883
#   Average l_n: 0.2655
#   Average l_d: -1.0001
#   Average l_nd: -0.7346
#
# yy
# breaking
# 100
# Finished epoch 2: 439.254s
#   Average loss: 0.2969
#   Average l_n: 0.2702
#   Average l_d: -0.9969
#   Average l_nd: -0.7267
#
# yy
# breaking
# 100
# Finished epoch 3: 661.576s
#   Average loss: 0.2940
#   Average l_n: 0.2727
#   Average l_d: -0.9985
#   Average l_nd: -0.7258
#
# yy
# breaking
# 100
# Finished epoch 4: 882.513s
#   Average loss: 0.2897
#   Average l_n: 0.2665
#   Average l_d: -1.0008
#   Average l_nd: -0.7342
#
# yy
# breaking
# 100
# Finished epoch 5: 1103.890s
#   Average loss: 0.2856
#   Average l_n: 0.2614
#   Average l_d: -1.0004
#   Average l_nd: -0.7391
#
# lr: 0.0001, beta1: 0.8, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 221.742s
#   Average loss: 0.2953
#   Average l_n: 0.2710
#   Average l_d: -0.9957
#   Average l_nd: -0.7247
#
# yy
# breaking
# 100
# Finished epoch 2: 440.259s
#   Average loss: 0.2879
#   Average l_n: 0.2631
#   Average l_d: -0.9962
#   Average l_nd: -0.7331
#
# yy
# breaking
# 100
# Finished epoch 3: 661.274s
#   Average loss: 0.2959
#   Average l_n: 0.2729
#   Average l_d: -0.9960
#   Average l_nd: -0.7230
#
# yy
# breaking
# 100
# Finished epoch 4: 882.494s
#   Average loss: 0.2908
#   Average l_n: 0.2686
#   Average l_d: -0.9999
#   Average l_nd: -0.7313
#
# yy
# breaking
# 100
# Finished epoch 5: 1100.626s
#   Average loss: 0.2973
#   Average l_n: 0.2692
#   Average l_d: -0.9902
#   Average l_nd: -0.7210
#
# lr: 0.0001, beta1: 0.9, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 221.192s
#   Average loss: 0.2940
#   Average l_n: 0.2695
#   Average l_d: -0.9947
#   Average l_nd: -0.7252
#
# yy
# breaking
# 100
# Finished epoch 2: 443.211s
#   Average loss: 0.2905
#   Average l_n: 0.2662
#   Average l_d: -1.0015
#   Average l_nd: -0.7353
#
# yy
# breaking
# 100
# Finished epoch 3: 661.623s
#   Average loss: 0.2922
#   Average l_n: 0.2686
#   Average l_d: -0.9945
#   Average l_nd: -0.7259
#
# yy
# breaking
# 100
# Finished epoch 4: 880.677s
#   Average loss: 0.2926
#   Average l_n: 0.2706
#   Average l_d: -0.9971
#   Average l_nd: -0.7265
#
# yy
# breaking
# 100
# Finished epoch 5: 1104.140s
#   Average loss: 0.2956
#   Average l_n: 0.2696
#   Average l_d: -0.9949
#   Average l_nd: -0.7253
#
# lr: 0.0003, beta1: 0.5, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 223.546s
#   Average loss: 0.2950
#   Average l_n: 0.2736
#   Average l_d: -1.0001
#   Average l_nd: -0.7265
#
# yy
# breaking
# 100
# Finished epoch 2: 446.651s
#   Average loss: 0.2921
#   Average l_n: 0.2715
#   Average l_d: -1.0005
#   Average l_nd: -0.7290
#
# yy
# breaking
# 100
# Finished epoch 3: 670.820s
#   Average loss: 0.2875
#   Average l_n: 0.2632
#   Average l_d: -1.0017
#   Average l_nd: -0.7385
#
# yy
# breaking
# 100
# Finished epoch 4: 893.170s
#   Average loss: 0.2954
#   Average l_n: 0.2713
#   Average l_d: -0.9931
#   Average l_nd: -0.7217
#
# yy
# breaking
# 100
# Finished epoch 5: 1116.017s
#   Average loss: 0.2901
#   Average l_n: 0.2668
#   Average l_d: -0.9989
#   Average l_nd: -0.7321
#
# lr: 0.0003, beta1: 0.6, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 221.940s
#   Average loss: 0.2918
#   Average l_n: 0.2677
#   Average l_d: -1.0006
#   Average l_nd: -0.7329
#
# yy
# breaking
# 100
# Finished epoch 2: 441.103s
#   Average loss: 0.2922
#   Average l_n: 0.2703
#   Average l_d: -0.9931
#   Average l_nd: -0.7228
#
# yy
# breaking
# 100
# Finished epoch 3: 662.914s
#   Average loss: 0.2870
#   Average l_n: 0.2630
#   Average l_d: -0.9968
#   Average l_nd: -0.7338
#
# yy
# breaking
# 100
# Finished epoch 4: 883.160s
#   Average loss: 0.2909
#   Average l_n: 0.2634
#   Average l_d: -0.9921
#   Average l_nd: -0.7287
#
# yy
# breaking
# 100
# Finished epoch 5: 1104.258s
#   Average loss: 0.2886
#   Average l_n: 0.2645
#   Average l_d: -0.9945
#   Average l_nd: -0.7301
#
# lr: 0.0003, beta1: 0.7, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 217.747s
#   Average loss: 0.2969
#   Average l_n: 0.2728
#   Average l_d: -0.9978
#   Average l_nd: -0.7250
#
# yy
# breaking
# 100
# Finished epoch 2: 441.090s
#   Average loss: 0.2926
#   Average l_n: 0.2693
#   Average l_d: -0.9994
#   Average l_nd: -0.7302
#
# yy
# breaking
# 100
# Finished epoch 3: 660.656s
#   Average loss: 0.2919
#   Average l_n: 0.2703
#   Average l_d: -0.9998
#   Average l_nd: -0.7294
#
# yy
# breaking
# 100
# Finished epoch 4: 883.429s
#   Average loss: 0.2945
#   Average l_n: 0.2678
#   Average l_d: -0.9964
#   Average l_nd: -0.7286
#
# yy
# breaking
# 100
# Finished epoch 5: 1110.380s
#   Average loss: 0.2893
#   Average l_n: 0.2621
#   Average l_d: -0.9969
#   Average l_nd: -0.7348
#
# lr: 0.0003, beta1: 0.8, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 223.304s
#   Average loss: 0.2935
#   Average l_n: 0.2696
#   Average l_d: -0.9942
#   Average l_nd: -0.7246
#
# yy
# breaking
# 100
# Finished epoch 2: 446.186s
#   Average loss: 0.2896
#   Average l_n: 0.2658
#   Average l_d: -0.9954
#   Average l_nd: -0.7296
#
# yy
# breaking
# 100
# Finished epoch 3: 667.678s
#   Average loss: 0.2830
#   Average l_n: 0.2600
#   Average l_d: -1.0015
#   Average l_nd: -0.7414
#
# yy
# breaking
# 100
# Finished epoch 4: 892.062s
#   Average loss: 0.2951
#   Average l_n: 0.2695
#   Average l_d: -0.9911
#   Average l_nd: -0.7215
#
# yy
# breaking
# 100
# Finished epoch 5: 1114.902s
#   Average loss: 0.2889
#   Average l_n: 0.2652
#   Average l_d: -0.9982
#   Average l_nd: -0.7330
#
# lr: 0.0003, beta1: 0.9, margin: 15
# yy
# breaking
# 100
# Finished epoch 1: 222.331s
#   Average loss: 0.2904
#   Average l_n: 0.2657
#   Average l_d: -0.9971
#   Average l_nd: -0.7314
#
# yy
# breaking
# 100
# Finished epoch 2: 444.907s
#   Average loss: 0.2967
#   Average l_n: 0.2750
#   Average l_d: -0.9958
#   Average l_nd: -0.7208
#
# yy
# breaking
# 100
# Finished epoch 3: 666.996s
#   Average loss: 0.2953
#   Average l_n: 0.2753
#   Average l_d: -0.9982
#   Average l_nd: -0.7229
#
# yy
# breaking
# 100
# Finished epoch 4: 890.204s
#   Average loss: 0.2920
#   Average l_n: 0.2688
#   Average l_d: -1.0000
#   Average l_nd: -0.7311
#
# yy
# breaking
# 100
# Finished epoch 5: 1113.852s
#   Average loss: 0.2880
#   Average l_n: 0.2650
#   Average l_d: -1.0004
#   Average l_nd: -0.7355
#
# lr: 0.01, beta1: 0.5, margin: 20
# yy
# breaking
# 100
# Finished epoch 1: 220.126s
#   Average loss: 0.3956
#   Average l_n: 0.3301
#   Average l_d: -1.2694
#   Average l_nd: -0.9394
#
# yy
# breaking
# 100
# Finished epoch 2: 441.915s
#   Average loss: 0.3972
#   Average l_n: 0.3551
#   Average l_d: -1.3198
#   Average l_nd: -0.9647
#
# yy
# breaking
# 100
# Finished epoch 3: 666.270s
#   Average loss: 0.3913
#   Average l_n: 0.3504
#   Average l_d: -1.3303
#   Average l_nd: -0.9799
#
# yy
# breaking
# 100
# Finished epoch 4: 890.409s
#   Average loss: 0.4003
#   Average l_n: 0.3537
#   Average l_d: -1.3170
#   Average l_nd: -0.9633
#
# yy
# breaking
# 100
# Finished epoch 5: 1113.386s
#   Average loss: 0.3917
#   Average l_n: 0.3546
#   Average l_d: -1.3304
#   Average l_nd: -0.9758
#
# lr: 0.01, beta1: 0.6, margin: 20
# yy
# breaking
# 100
# Finished epoch 1: 224.369s
#   Average loss: 0.4021
#   Average l_n: 0.3612
#   Average l_d: -1.3277
#   Average l_nd: -0.9665
#
# yy
# breaking
# 100
# Finished epoch 2: 447.763s
#   Average loss: 0.3922
#   Average l_n: 0.3540
#   Average l_d: -1.3307
#   Average l_nd: -0.9767
#
# yy
# breaking
# 100
# Finished epoch 3: 671.514s
#   Average loss: 0.3894
#   Average l_n: 0.3445
#   Average l_d: -1.3221
#   Average l_nd: -0.9776
#
# yy
# breaking
# 100
# Finished epoch 4: 896.354s
#   Average loss: 0.3929
#   Average l_n: 0.3550
#   Average l_d: -1.3400
#   Average l_nd: -0.9850
#
# yy
# breaking
# 100
# Finished epoch 5: 1119.832s
#   Average loss: 0.3877
#   Average l_n: 0.3584
#   Average l_d: -1.3407
#   Average l_nd: -0.9824
#
# lr: 0.01, beta1: 0.7, margin: 20
# yy
# breaking
# 100
# Finished epoch 1: 224.380s
#   Average loss: 0.3844
#   Average l_n: 0.3483
#   Average l_d: -1.3332
#   Average l_nd: -0.9849
#
# yy
# breaking
# 100
# Finished epoch 2: 445.225s
#   Average loss: 0.3885
#   Average l_n: 0.3480
#   Average l_d: -1.3225
#   Average l_nd: -0.9745
#
# yy
# breaking
# 100
# Finished epoch 3: 671.985s
#   Average loss: 0.3902
#   Average l_n: 0.3500
#   Average l_d: -1.3250
#   Average l_nd: -0.9750
#
# yy
# breaking
# 100
# Finished epoch 4: 893.925s
#   Average loss: 0.3914
#   Average l_n: 0.3521
#   Average l_d: -1.3246
#   Average l_nd: -0.9725
#
# yy
# breaking
# 100
# Finished epoch 5: 1116.194s
#   Average loss: 0.3904
#   Average l_n: 0.3529
#   Average l_d: -1.3307
#   Average l_nd: -0.9779
#
# lr: 0.01, beta1: 0.8, margin: 20
# yy
# breaking
# 100
# Finished epoch 1: 223.471s
#   Average loss: 0.3851
#   Average l_n: 0.3511
#   Average l_d: -1.3374
#   Average l_nd: -0.9863
#
# yy
# breaking
# 100
# Finished epoch 2: 444.286s
#   Average loss: 0.3956
#   Average l_n: 0.3560
#   Average l_d: -1.3283
#   Average l_nd: -0.9723
#
# yy
# breaking
# 100
# Finished epoch 3: 666.151s
#   Average loss: 0.3876
#   Average l_n: 0.3440
#   Average l_d: -1.3168
#   Average l_nd: -0.9727
#
# yy
# breaking
# 100
# Finished epoch 4: 886.093s
#   Average loss: 0.3928
#   Average l_n: 0.3565
#   Average l_d: -1.3230
#   Average l_nd: -0.9665
#
# yy
# breaking
# 100
# Finished epoch 5: 1106.427s
#   Average loss: 0.3913
#   Average l_n: 0.3537
#   Average l_d: -1.3352
#   Average l_nd: -0.9815
#
# lr: 0.01, beta1: 0.9, margin: 20
# yy
# breaking
# 100
# Finished epoch 1: 220.411s
#   Average loss: 0.3955
#   Average l_n: 0.3578
#   Average l_d: -1.3235
#   Average l_nd: -0.9657
#
# yy
# breaking
# 100
# Finished epoch 2: 442.556s
#   Average loss: 0.3899
#   Average l_n: 0.3590
#   Average l_d: -1.3433
#   Average l_nd: -0.9843
#
# yy
# breaking
# 100
# Finished epoch 3: 664.616s
#   Average loss: 0.3873
#   Average l_n: 0.3508
#   Average l_d: -1.3306
#   Average l_nd: -0.9798
#
# yy
# breaking
# 100
# Finished epoch 4: 888.661s
#   Average loss: 0.3904
#   Average l_n: 0.3589
#   Average l_d: -1.3403
#   Average l_nd: -0.9815
#
# yy
# breaking
# 100
# Finished epoch 5: 1110.298s
#   Average loss: 0.3888
#   Average l_n: 0.3525
#   Average l_d: -1.3318
#   Average l_nd: -0.9793
#
# lr: 0.03, beta1: 0.5, margin: 20
# yy
# breaking
# 100
# Finished epoch 1: 220.216s
#   Average loss: 0.4004
#   Average l_n: 0.3683
#   Average l_d: -1.3479
#   Average l_nd: -0.9796
#
# yy
# breaking
# 100
# Finished epoch 2: 440.838s
#   Average loss: 0.4006
#   Average l_n: 0.3736
#   Average l_d: -1.3661
#   Average l_nd: -0.9925
#
# yy
# breaking
# 100
# Finished epoch 3: 661.270s
#   Average loss: 0.4063
#   Average l_n: 0.3731
#   Average l_d: -1.3477
#   Average l_nd: -0.9746
#
# yy
# breaking
# 100
# Finished epoch 4: 881.984s
#   Average loss: 0.4084
#   Average l_n: 0.3684
#   Average l_d: -1.3460
#   Average l_nd: -0.9776
#
# yy
# breaking
# 100
# Finished epoch 5: 1105.127s
#   Average loss: 0.4040
#   Average l_n: 0.3645
#   Average l_d: -1.3465
#   Average l_nd: -0.9820
#
# lr: 0.03, beta1: 0.6, margin: 20
# yy
# breaking
# 100
# Finished epoch 1: 225.757s
#   Average loss: 0.4073
#   Average l_n: 0.3702
#   Average l_d: -1.3448
#   Average l_nd: -0.9746
#
# yy
# breaking
# 100
# Finished epoch 2: 446.009s
#   Average loss: 0.4096
#   Average l_n: 0.3752
#   Average l_d: -1.3572
#   Average l_nd: -0.9820
#
# yy
# breaking
# 100
# Finished epoch 3: 668.538s
#   Average loss: 0.4045
#   Average l_n: 0.3750
#   Average l_d: -1.3605
#   Average l_nd: -0.9855
#
# yy
# breaking
# 100
# Finished epoch 4: 889.929s
#   Average loss: 0.4022
#   Average l_n: 0.3744
#   Average l_d: -1.3623
#   Average l_nd: -0.9879
#
# yy
# breaking
# 100
# Finished epoch 5: 1110.146s
#   Average loss: 0.4053
#   Average l_n: 0.3754
#   Average l_d: -1.3612
#   Average l_nd: -0.9858
#
# lr: 0.03, beta1: 0.7, margin: 20
# yy
# breaking
# 100
# Finished epoch 1: 225.416s
#   Average loss: 0.4045
#   Average l_n: 0.3742
#   Average l_d: -1.3610
#   Average l_nd: -0.9868
#
# yy
# breaking
# 100
# Finished epoch 2: 451.671s
#   Average loss: 0.4052
#   Average l_n: 0.3796
#   Average l_d: -1.3598
#   Average l_nd: -0.9801
#
# yy
# breaking
# 100
# Finished epoch 3: 678.100s
#   Average loss: 0.3973
#   Average l_n: 0.3648
#   Average l_d: -1.3561
#   Average l_nd: -0.9914
#
# yy
# breaking
# 100
# Finished epoch 4: 903.692s
#   Average loss: 0.4082
#   Average l_n: 0.3791
#   Average l_d: -1.3584
#   Average l_nd: -0.9794
#
# yy
# breaking
# 100
# Finished epoch 5: 1124.159s
#   Average loss: 0.4075
#   Average l_n: 0.3731
#   Average l_d: -1.3545
#   Average l_nd: -0.9814
#
# lr: 0.03, beta1: 0.8, margin: 20
# yy
# breaking
# 100
# Finished epoch 1: 221.004s
#   Average loss: 0.3986
#   Average l_n: 0.3729
#   Average l_d: -1.3622
#   Average l_nd: -0.9893
#
# yy
# breaking
# 100
# Finished epoch 2: 446.734s
#   Average loss: 0.3958
#   Average l_n: 0.3587
#   Average l_d: -1.3465
#   Average l_nd: -0.9878
#
# yy
# breaking
# 100
# Finished epoch 3: 668.848s
#   Average loss: 0.3927
#   Average l_n: 0.3544
#   Average l_d: -1.3452
#   Average l_nd: -0.9909
#
# yy
# breaking
# 100
# Finished epoch 4: 889.847s
#   Average loss: 0.4044
#   Average l_n: 0.3713
#   Average l_d: -1.3527
#   Average l_nd: -0.9814
#
# yy
# breaking
# 100
# Finished epoch 5: 1112.005s
#   Average loss: 0.4013
#   Average l_n: 0.3711
#   Average l_d: -1.3577
#   Average l_nd: -0.9866
#
# lr: 0.03, beta1: 0.9, margin: 20
# yy
# breaking
# 100
# Finished epoch 1: 224.142s
#   Average loss: 0.4056
#   Average l_n: 0.3724
#   Average l_d: -1.3588
#   Average l_nd: -0.9864
#
# yy
# breaking
# 100
# Finished epoch 2: 449.201s
#   Average loss: 0.3969
#   Average l_n: 0.3571
#   Average l_d: -1.3441
#   Average l_nd: -0.9871
#
# yy
# breaking
# 100
# Finished epoch 3: 668.781s
#   Average loss: 0.4076
#   Average l_n: 0.3703
#   Average l_d: -1.3557
#   Average l_nd: -0.9854
#
# yy
# breaking
# 100
# Finished epoch 4: 891.288s
#   Average loss: 0.4022
#   Average l_n: 0.3684
#   Average l_d: -1.3512
#   Average l_nd: -0.9828
#
# yy
# breaking
# 100
# Finished epoch 5: 1111.672s
#   Average loss: 0.3961
#   Average l_n: 0.3677
#   Average l_d: -1.3629
#   Average l_nd: -0.9952
#
# lr: 0.001, beta1: 0.5, margin: 20
# yy
# breaking
# 100
# Finished epoch 1: 223.185s
#   Average loss: 0.4015
#   Average l_n: 0.3725
#   Average l_d: -1.3657
#   Average l_nd: -0.9932
#
# yy
# breaking
# 100
# Finished epoch 2: 443.801s
#   Average loss: 0.3906
#   Average l_n: 0.3604
#   Average l_d: -1.3703
#   Average l_nd: -1.0099
#
# yy
# breaking
# 100
# Finished epoch 3: 665.614s
#   Average loss: 0.4041
#   Average l_n: 0.3731
#   Average l_d: -1.3497
#   Average l_nd: -0.9766
#
# yy
# breaking
# 100
# Finished epoch 4: 893.404s
#   Average loss: 0.3882
#   Average l_n: 0.3528
#   Average l_d: -1.3469
#   Average l_nd: -0.9941
#
# yy
# breaking
# 100
# Finished epoch 5: 1115.563s
#   Average loss: 0.3876
#   Average l_n: 0.3543
#   Average l_d: -1.3407
#   Average l_nd: -0.9864
#
# lr: 0.001, beta1: 0.6, margin: 20
# yy
# breaking
# 100
# Finished epoch 1: 222.226s
#   Average loss: 0.3875
#   Average l_n: 0.3513
#   Average l_d: -1.3359
#   Average l_nd: -0.9845
#
# yy
# breaking
# 100
# Finished epoch 2: 444.708s
#   Average loss: 0.3884
#   Average l_n: 0.3568
#   Average l_d: -1.3412
#   Average l_nd: -0.9844
#
# yy
# breaking
# 100
# Finished epoch 3: 666.483s
#   Average loss: 0.3895
#   Average l_n: 0.3548
#   Average l_d: -1.3441
#   Average l_nd: -0.9893
#
# yy
# breaking
# 100
# Finished epoch 4: 889.577s
#   Average loss: 0.3872
#   Average l_n: 0.3487
#   Average l_d: -1.3315
#   Average l_nd: -0.9828
#
# yy
# breaking
# 100
# Finished epoch 5: 1110.532s
#   Average loss: 0.3788
#   Average l_n: 0.3444
#   Average l_d: -1.3339
#   Average l_nd: -0.9895
#
# lr: 0.001, beta1: 0.7, margin: 20
# yy
# breaking
# 100
# Finished epoch 1: 224.338s
#   Average loss: 0.3901
#   Average l_n: 0.3526
#   Average l_d: -1.3308
#   Average l_nd: -0.9783
#
# yy
# breaking
# 100
# Finished epoch 2: 444.146s
#   Average loss: 0.3859
#   Average l_n: 0.3586
#   Average l_d: -1.3407
#   Average l_nd: -0.9821
#
# yy
# breaking
# 100
# Finished epoch 3: 664.608s
#   Average loss: 0.3893
#   Average l_n: 0.3555
#   Average l_d: -1.3330
#   Average l_nd: -0.9775
#
# yy
# breaking
# 100
# Finished epoch 4: 884.101s
#   Average loss: 0.3843
#   Average l_n: 0.3477
#   Average l_d: -1.3273
#   Average l_nd: -0.9796
#
# yy
# breaking
# 100
# Finished epoch 5: 1108.207s
#   Average loss: 0.3851
#   Average l_n: 0.3473
#   Average l_d: -1.3255
#   Average l_nd: -0.9783
#
# lr: 0.001, beta1: 0.8, margin: 20
# yy
# breaking
# 100
# Finished epoch 1: 223.873s
#   Average loss: 0.3826
#   Average l_n: 0.3424
#   Average l_d: -1.3226
#   Average l_nd: -0.9802
#
# yy
# breaking
# 100
# Finished epoch 2: 446.432s
#   Average loss: 0.3772
#   Average l_n: 0.3396
#   Average l_d: -1.3166
#   Average l_nd: -0.9769
#
# yy
# breaking
# 100
# Finished epoch 3: 669.500s
#   Average loss: 0.3791
#   Average l_n: 0.3375
#   Average l_d: -1.3239
#   Average l_nd: -0.9864
#
# yy
# breaking
# 100
# Finished epoch 4: 892.752s
#   Average loss: 0.3796
#   Average l_n: 0.3401
#   Average l_d: -1.3207
#   Average l_nd: -0.9807
#
# yy
# breaking
# 100
# Finished epoch 5: 1113.603s
#   Average loss: 0.3837
#   Average l_n: 0.3480
#   Average l_d: -1.3203
#   Average l_nd: -0.9723
#
# lr: 0.001, beta1: 0.9, margin: 20
# yy
# breaking
# 100
# Finished epoch 1: 220.124s
#   Average loss: 0.3842
#   Average l_n: 0.3468
#   Average l_d: -1.3230
#   Average l_nd: -0.9762
#
# yy
# breaking
# 100
# Finished epoch 2: 442.130s
#   Average loss: 0.3784
#   Average l_n: 0.3418
#   Average l_d: -1.3219
#   Average l_nd: -0.9800
#
# yy
# breaking
# 100
# Finished epoch 3: 662.742s
#   Average loss: 0.3865
#   Average l_n: 0.3463
#   Average l_d: -1.3234
#   Average l_nd: -0.9771
#
# yy
# breaking
# 100
# Finished epoch 4: 886.329s
#   Average loss: 0.3811
#   Average l_n: 0.3393
#   Average l_d: -1.3259
#   Average l_nd: -0.9866
#
# yy
# breaking
# 100
# Finished epoch 5: 1107.805s
#   Average loss: 0.3803
#   Average l_n: 0.3389
#   Average l_d: -1.3198
#   Average l_nd: -0.9809
#
# lr: 0.003, beta1: 0.5, margin: 20
# yy
# breaking
# 100
# Finished epoch 1: 225.916s
#   Average loss: 0.3873
#   Average l_n: 0.3429
#   Average l_d: -1.3110
#   Average l_nd: -0.9681
#
# yy
# breaking
# 100
# Finished epoch 2: 447.561s
#   Average loss: 0.3834
#   Average l_n: 0.3476
#   Average l_d: -1.3313
#   Average l_nd: -0.9837
#
# yy
# breaking
# 100
# Finished epoch 3: 674.475s
#   Average loss: 0.3801
#   Average l_n: 0.3388
#   Average l_d: -1.3192
#   Average l_nd: -0.9805
#
# yy
# breaking
# 100
# Finished epoch 4: 897.867s
#   Average loss: 0.3849
#   Average l_n: 0.3505
#   Average l_d: -1.3290
#   Average l_nd: -0.9785
#
# yy
# breaking
# 100
# Finished epoch 5: 1122.730s
#   Average loss: 0.3896
#   Average l_n: 0.3447
#   Average l_d: -1.3142
#   Average l_nd: -0.9695
#
# lr: 0.003, beta1: 0.6, margin: 20
# yy
# breaking
# 100
# Finished epoch 1: 226.226s
#   Average loss: 0.3747
#   Average l_n: 0.3352
#   Average l_d: -1.3202
#   Average l_nd: -0.9850
#
# yy
# breaking
# 100
# Finished epoch 2: 443.931s
#   Average loss: 0.3841
#   Average l_n: 0.3465
#   Average l_d: -1.3193
#   Average l_nd: -0.9728
#
# yy
# breaking
# 100
# Finished epoch 3: 668.663s
#   Average loss: 0.3819
#   Average l_n: 0.3485
#   Average l_d: -1.3261
#   Average l_nd: -0.9776
#
# yy
# breaking
# 100
# Finished epoch 4: 889.952s
#   Average loss: 0.3791
#   Average l_n: 0.3418
#   Average l_d: -1.3188
#   Average l_nd: -0.9770
#
# yy
# breaking
# 100
# Finished epoch 3: 672.685s
#   Average loss: 0.3721
#   Average l_n: 0.3308
#   Average l_d: -1.3129
#   Average l_nd: -0.9821
#
# yy
# breaking
# 100
# Finished epoch 4: 896.646s
#   Average loss: 0.3794
#   Average l_n: 0.3350
#   Average l_d: -1.3091
#   Average l_nd: -0.9741
#
# yy

# %%
for params, plot_list in all_plots:
    print('lr: {}, beta1: {}, margin: {}'.format(params[0], params[1], params[2]), plot_list)

# %% [markdown]
# # Pre Process Y Values

# %%
#note to self: need to embed tiles first and then figure out loop for reading in the saved model and plotting
#the classification accuracies per epoch
tile_dir = '../data/tiles'
n_tiles = 1000
y = np.load(os.path.join(tile_dir, 'y.npy'))
print(y.shape)
#print(set(y))

# %%
# Check CDL classes
print(set(y))

# %%
y = LabelEncoder().fit_transform(y)
print(set(y))

# %% [markdown]
# # Load in Epochs' Weights + Run each on tile embeddings + Random Forest

# %%
#set up model
in_channels = 4
z_dim = 512
cuda = torch.cuda.is_available()

# %%
def getTileEmbeddings(tilenet):
    X = np.zeros((n_tiles, z_dim))
    for idx in range(n_tiles):
        tile = np.load(os.path.join(tile_dir, '{}tile.npy'.format(idx+1)))
        # Get first 4 NAIP channels (5th is CDL mask)
        tile = tile[:,:,:4]
        # Rearrange to PyTorch order
        tile = np.moveaxis(tile, -1, 0)
        tile = np.expand_dims(tile, axis=0)
        # Scale to [0, 1]
        tile = tile / 255
        # Embed tile
        tile = torch.from_numpy(tile).float()
        tile = Variable(tile)
        if cuda: tile = tile.cuda()
        z = tilenet.encode(tile)
        if cuda: z = z.cpu()
        z = z.data.numpy() #1 by 512
        X[idx,:] = z
    return X

# %%
epochsToAccuracy = []
epochsToSTD = []
for i in range(0,epochs): #iterator
    curEpoch = i + 1
    # Setting up model
    tilenet = ResNet18()
    if cuda: tilenet.cuda()
    model_fn = "../models/test1_ep"+str(curEpoch)+".ckpt" #open file
    #checkpoint = torch.load(model_fn)
    tilenet.load_state_dict(torch.load(model_fn), strict=False)
    #tilenet.load_state_dict(checkpoint)
    tilenet.eval()
    
    X = getTileEmbeddings(tilenet) #function above
    
    #train random forest classifier
    n_trials = 100
    accs = np.zeros((n_trials,))
    for i in range(n_trials):
        # Splitting data and training RF classifer
        X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.2)
        rf = RandomForestClassifier()
        rf.fit(X_tr, y_tr) #X-tr is 512 by 1
        accs[i] = rf.score(X_te, y_te)
    print("Results for Epoch Number: ", str(curEpoch))
    print('Mean accuracy: {:0.4f}'.format(accs.mean()))
    print('Standard deviation: {:0.4f}'.format(accs.std()))
    epochsToAccuracy.append((curEpoch,accs.mean()))
    epochsToSTD.append((curEpoch,accs.std()))
print(epochsToAccuracy)
print(epochsToSTD)
    #save value

# %%
print(epochsToSTD)

# %%
import matplotlib.pyplot as plt
plt.plot(*zip(*epochsToAccuracy))
plt.title('Triplet Augmentation Average Test Performance')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()
print(epochsToAccuracy[9][1], "was the Max Accuracy")

# %%
plt.plot(*zip(*plot_list))
plt.title('Triplet Augmentation Loss Performance')
plt.xlabel('Epochs')
plt.ylabel('Loss')
print("The min loss was",str(plot_list[9][1]))
plt.show()

# %%
plt.plot(*zip(*epochsToSTD))
plt.title('STD on Random Forest Test Prediction')
plt.xlabel('Epochs')
plt.ylabel('Standard Deviation')
plt.show()
